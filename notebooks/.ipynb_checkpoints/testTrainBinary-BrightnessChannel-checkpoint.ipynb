# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import os
from oiffile import imread
from PIL import Image
import random
import skimage
from skimage.transform import resize
import matplotlib
import glob
import torch
import sys
sys.path.insert(0, '..')
import scipy.io as sio
import matplotlib.patches as patches
from skimage.measure import label,regionprops
from matplotlib_scalebar.scalebar import ScaleBar
from skimage.transform import rescale
import dognet
import functions
from sklearn.metrics import roc_curve, auc
import os, os.path
# %matplotlib inline
from skimage.draw import circle

# %%
nets = [[[],[]],[[],[]],[[],[]],[[],[]],[[],[]]]
errorList = [[[],[]],[[],[]],[[],[]],[[],[]],[[],[]]]

ivalues=[13,14,15,16,17]
jvalues=[1e-3,1e-4]

for i in range(0,5):
    #get training masks
    path1 = glob.glob("../datasets/flocculusA/trainingMasks/*.npy")
    trainingMasks = functions.get_trainingMasks(path1)
    #get and scale training images
    path2 = glob.glob("../datasets/flocculusA/trainingImages3/*.npy")
    trainingImages,collman = functions.get_trainingImages(path2,ivalues[i])
    
    imagestraining=[0,1,2,3,5,6,8,9,10,12,13,14,15,16,17,19,20,21,22,24,26,28,29,31,32,33,34]
    imagestesting=[4,7,11,18,23,25,27,30,35]

    newTrainingImages=[]
    newTrainingMasks=[]

    for k in range(0,27):
        newTrainingImages.append(trainingImages[k])
        newTrainingMasks.append(trainingMasks[k])
        
    for j in range(0,2):
        device = torch.device("cpu")
        net = dognet.SimpleAnisotropic(3,15,27).to(device)
        net.weights_init()
        #print(dognet.get_n_params(net))
        net,errors =dognet.train_routine(net.to(device),dognet.create_generator(newTrainingImages,newTrainingMasks),n_iter=800,margin=5,loss='softdice',lr=jvalues[j])
        nets[i][j] = net
        errorList[i][j]= errors
# Out:
# tensor([40934.]) (10, 1, 64, 64) 4096 0.0 0.0
# <function soft_dice_loss at 0x12a4e9ea0>
# Training started!
# [====================] 100%
# Training finished!
# tensor([40713.]) (10, 1, 64, 64) 4096 0.0 0.0
# <function soft_dice_loss at 0x12a4e9ea0>
# Training started!
# [====================] 100%
# Training finished!
# tensor([40960.]) (10, 1, 64, 64) 4096 0.0 0.0
# <function soft_dice_loss at 0x12a4e9ea0>
# Training started!
# [====================] 100%
# Training finished!
# tensor([40959.]) (10, 1, 64, 64) 4096 0.0 0.0
# <function soft_dice_loss at 0x12a4e9ea0>
# Training started!
# [====================] 100%
# Training finished!
# tensor([40858.]) (10, 1, 64, 64) 4096 0.0 0.0
# <function soft_dice_loss at 0x12a4e9ea0>
# Training started!
# [====================] 100%
# Training finished!
# tensor([40811.]) (10, 1, 64, 64) 4096 0.0 0.0
# <function soft_dice_loss at 0x12a4e9ea0>
# Training started!
# [====================] 100%
# Training finished!
# tensor([40841.]) (10, 1, 64, 64) 4096 0.0 0.0
# <function soft_dice_loss at 0x12a4e9ea0>
# Training started!
# [====================] 100%
# Training finished!
# tensor([40868.]) (10, 1, 64, 64) 4096 0.0 0.0
# <function soft_dice_loss at 0x12a4e9ea0>
# Training started!
# [====================] 100%
# Training finished!
# tensor([408.6000]) (10, 1, 64, 64) 4096 100.0 1.0
# <function soft_dice_loss at 0x12a4e9ea0>
# Training started!
# [====================] 100%
# Training finished!
# tensor([40960.]) (10, 1, 64, 64) 4096 0.0 0.0
# <function soft_dice_loss at 0x12a4e9ea0>
# Training started!
# [====================] 100%
# Training finished!

# %%
for i in range(0,5):
    for j in range(0,2):
        if i==0:
            sc="13"
        elif i==1:
            sc="14"
        elif i==2:
            sc="15"
        elif i==3:
            sc="16"
        elif i==4:
            sc="17"
        if j==0:
            lrN="1e-3"
        elif j == 1:
            lrN="1e-4"
        
        nName="newnet_%s_%s" % (sc,lrN)
        
        torch.save(nets[i][j], nName)

# %%
#x=random.choice([4,7,11,18,23,25,30,35])
x=23
print(x)
testingNumber=1
#plt.figure(figsize=(20,20))


for i in range(0,5):
    for j in range(0,1):
        b = functions.get_coords(x,testingNumber,len(trainingImages))
        #plt.subplot(2,3,i+j+1)
        #plt.imshow(functions.estimate_quality(collman,nets[i][j],b,range(x,x+1)))
        functions.show_prediction(x,testingNumber,trainingImages,trainingMasks,collman,nets[i][j],b)
# Out:
# 23

# %%
plt.plot(errorList[0][0])
plt.plot(errorList[1][0])
plt.plot(errorList[2][0])
plt.plot(errorList[3][0])
plt.plot(errorList[4][0])
plt.legend(['13','14','15','16','17'])

# %%
#x=random.randint(0,len(trainingImages)-2)
x=random.choice([4,7,11,18,23,25,30,35])
print(x)
testingNumber=1
b = functions.get_coords(x,testingNumber,len(trainingImages))
functions.show_prediction(x,testingNumber,trainingImages,trainingMasks,collman,net,b)
# Out:
# 23

# %%
#x=random.randint(0,len(trainingImages)-2)
imagestesting=[4,7,11,18,23,25,30,35]

for i in imagestesting:

#x=random.choice([4,7,11,18,23,25,27,30,35])
    x=i
    testingNumber=1
    b = functions.get_coords(x,testingNumber,len(trainingImages))
    functions.show_prediction(x,testingNumber,trainingImages,trainingMasks,collman,net,b)

# %%
plt.figure(figsize=(20,20))
plt.subplot(2,2,1)
functions.estimate_quality(collman,net,b,slices=range(x,x+1))
plt.imshow(trainingMasks[x],'jet', interpolation='none', alpha=0.1)
plt.subplot(2,2,2)
functions.estimate_quality(collman,net,b,slices=range(x,x+1))
plt.imshow(trainingImages[x][1],'jet', interpolation='none', alpha=0.3)
plt.subplot(2,2,3)
functions.estimate_quality(collman,net,b,slices=range(x,x+1))
plt.imshow(collman[0][x])
plt.imshow(trainingMasks[x],'jet', interpolation='none', alpha=0.6)
plt.subplot(2,2,4)
plt.imshow(collman[1][x])
