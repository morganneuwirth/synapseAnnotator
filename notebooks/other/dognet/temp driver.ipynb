# %%
from unet import *
import torch
import matplotlib.pyplot as plot

# %%
x = torch.randn(1,3,460,460).to(torch.device('cuda'))

# %%
mynet = UNet(3,1).to(torch.device('cuda'))
y = mynet(x)
plot.imshow(y[0].detach().cpu().numpy().squeeze())
